# %%
from nltk.corpus import wordnet as wn

# %%
list(wn.all_lemma_names())
# Out:
# ['.22-caliber',
#  '.22-calibre',
#  '.22_caliber',
#  '.22_calibre',
#  '.38-caliber',
#  '.38-calibre',
#  '.38_caliber',
#  '.38_calibre',
#  '.45-caliber',
#  '.45-calibre',
#  '.45_caliber',
#  '.45_calibre',
#  '0',
#  '1',
#  '10',
#  '10-membered',
#  '100',
#  '1000',
#  '1000th',
#  '100th',
#  '101',
#  '101st',
#  '105',
#  '105th',
#  '10th',
#  '11',
#  '110',
#  '110th',
#  '115',
#  '115th',
#  '11th',
#  '12',
#  '120',
#  '120th',
#  '125',
#  '125th',
#  '12th',
#  '13',
#  '130',
#  '130th',
#  '135',
#  '135th',
#  '13th',
#  '14',
#  '140',
#  '140th',
#  '145',
#  '145th',
#  '14th',
#  '15',
#  '150',
#  '150th',
#  '155',
#  '155th',
#  '15th',
#  '16',
#  '160',
#  '160th',
#  '165',
#  '165th',
#  '16th',
#  '17',
#  '170',
#  '170th',
#  '175',
#  '175th',
#  '17th',
#  '18',
#  '180',
#  '180th',
#  '18th',
#  '19',
#  '190',
#  '190th',
#  '19th',
#  '1st',
#  '2',
#  '2-dimensional',
#  '20',
#  '200',
#  '200th',
#  '20th',
#  '21',
#  '21st',
# ...
