# %%
# %run main.py --dataset=WN18RR --num_iterations=100 --batch_size=128 --lr=0.003 --dr=1.0 --edim=200 --rdim=15 --input_dropout=0.2 --hidden_dropout1=0.2 --hidden_dropout2=0.3 --label_smoothing=0.1 --bk=True
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/rkbrary/ift6760-exp" target="_blank">https://app.wandb.ai/rkbrary/ift6760-exp</a><br/>
#                 Run page: <a href="https://app.wandb.ai/rkbrary/ift6760-exp/runs/1gm5tyxp" target="_blank">https://app.wandb.ai/rkbrary/ift6760-exp/runs/1gm5tyxp</a><br/>
# Training the TuckER model...
# Background knowledge=True
# Model= WN18RR
# Number of training data points: 86835
# mixed model
# Starting training...
# Exception in thread Thread-33:
# Traceback (most recent call last):
#   File "C:\Users\joss1\.conda\envs\torch\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\joss1\.conda\envs\torch\lib\site-packages\wandb\file_pusher.py", line 85, in run
#     self.cleanup_file()
# ...

# %%
dataset
# Out:
# 'WN18RR'

# %%
d.relations
# Out:
# ['_also_see',
#  '_derivationally_related_form',
#  '_has_part',
#  '_hypernym',
#  '_instance_hypernym',
#  '_member_meronym',
#  '_member_of_domain_region',
#  '_member_of_domain_usage',
#  '_similar_to',
#  '_synset_domain_topic_of',
#  '_verb_group']
# requests_with_retry encountered retryable exception: 500 Server Error: Internal Server Error for url: https://api.wandb.ai/files/rkbrary/ift6760-exp/1gm5tyxp/file_stream. args: ('https://api.wandb.ai/files/rkbrary/ift6760-exp/1gm5tyxp/file_stream',), kwargs: {'json': {'complete': False, 'failed': False}}
# requests_with_retry encountered retryable exception: ('Connection aborted.', ConnectionResetError(10054, 'Une connexion existante a dû être fermée par l’hôte distant', None, 10054, None)). args: ('https://api.wandb.ai/files/rkbrary/ift6760-exp/1gm5tyxp/file_stream',), kwargs: {'json': {'complete': False, 'failed': False}}

# %%
set(d.relations)-set(['_derivationally_related_form', '_verb_group', '_similar_to', '_synset_domain_topic_of', '_hypernym', '_also_see']
)
# Out:
# {'_has_part',
#  '_instance_hypernym',
#  '_member_meronym',
#  '_member_of_domain_region',
#  '_member_of_domain_usage'}
