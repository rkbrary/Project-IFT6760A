# %%
# %run main.py --dataset=WN18 --num_iterations=30 --batch_size=128 --lr=0.005 --dr=0.995 --edim=200 --rdim=30 --input_dropout=0.2 --hidden_dropout1=0.1 --hidden_dropout2=0.2 --label_smoothing=0.1
# Out:
# Training the TuckER model...
# Number of training data points: 282884
# Starting training...
# 1
# 52.85376501083374
# 0.01734823402967819
# Validation:
# Number of data points: 10000
# Hits @10: 0.0004
# Hits @3: 0.0003
# Hits @1: 0.0001
# Mean rank: 16820.3367
# Mean reciprocal rank: 0.00048655765969960905
# 2
# 53.76841926574707
# 0.0009104617688542452
# Validation:
# Number of data points: 10000
# Hits @10: 0.0031
# Hits @3: 0.0015
# Hits @1: 0.0004
# Mean rank: 15550.5781
# Mean reciprocal rank: 0.001732635011114515
# Test:
# Number of data points: 10000
# Hits @10: 0.0026
# Hits @3: 0.0012
# Hits @1: 0.0003
# Mean rank: 15556.1616
# Mean reciprocal rank: 0.0015400905806848928
# 17.505143880844116
# 3
# 53.891592264175415
# 0.0007355449890793734
# Validation:
# Number of data points: 10000
# Hits @10: 0.0221
# Hits @3: 0.0132
# Hits @1: 0.0076
# Mean rank: 14270.0206
# Mean reciprocal rank: 0.013007641553866784
# 4
# 54.33411693572998
# 0.0006600291452889842
# Validation:
# ...
