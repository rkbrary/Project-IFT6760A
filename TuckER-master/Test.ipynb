# %%
# %run main.py --dataset=WN18RR --num_iterations=100 --batch_size=128 --lr=0.003 --dr=1.0 --edim=200 --rdim=30 --input_dropout=0.2 --hidden_dropout1=0.2 --hidden_dropout2=0.3 --label_smoothing=0.1 --bk=False
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/rkbrary/ift6760-exp" target="_blank">https://app.wandb.ai/rkbrary/ift6760-exp</a><br/>
#                 Run page: <a href="https://app.wandb.ai/rkbrary/ift6760-exp/runs/3r3qvu8b" target="_blank">https://app.wandb.ai/rkbrary/ift6760-exp/runs/3r3qvu8b</a><br/>
# False
# Removing the redundant symmetric relations in the training set...
# Training the TuckER model...
# Number of training data points: 55902
# Exception in thread Thread-57:
# Traceback (most recent call last):
#   File "C:\Users\joss1\.conda\envs\torch\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\joss1\.conda\envs\torch\lib\site-packages\wandb\file_pusher.py", line 85, in run
#     self.cleanup_file()
#   File "C:\Users\joss1\.conda\envs\torch\lib\site-packages\wandb\file_pusher.py", line 152, in cleanup_file
#     super(BatchUploadJob, self).cleanup_file()
#   File "C:\Users\joss1\.conda\envs\torch\lib\site-packages\wandb\file_pusher.py", line 76, in cleanup_file
#     os.remove(self.save_path)
# PermissionError: [WinError 32] Le processus ne peut pas accéder au fichier car ce fichier est utilisé par un autre processus: 'C:\\Users\\joss1\\AppData\\Local\\Temp\\tmpadd8683iwandb\\___batch_archive_1.tgz'
# Starting training...
# Exception in thread Thread-58:
# Traceback (most recent call last):
#   File "C:\Users\joss1\.conda\envs\torch\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\joss1\.conda\envs\torch\lib\site-packages\wandb\file_pusher.py", line 85, in run
#     self.cleanup_file()
#   File "C:\Users\joss1\.conda\envs\torch\lib\site-packages\wandb\file_pusher.py", line 76, in cleanup_file
#     os.remove(self.save_path)
# PermissionError: [WinError 32] Le processus ne peut pas accéder au fichier car ce fichier est utilisé par un autre processus: 'C:\\Users\\joss1\\AppData\\Local\\Temp\\tmpadd8683iwandb\\config.yaml'
# Iteration:1
# Training Time:30.963090419769287
# Loss:0.10133128245951424
# Validation:
# Number of data points: 3034
# Hits @10: 0.0003295978905735003
# Hits @3: 0.0003295978905735003
# Hits @1: 0.0
# Mean rank: 19232.828279499012
# Mean reciprocal rank: 0.000310805238396987
# Iteration:2
# Training Time:26.20589518547058
# Loss:0.00584277920293766
# Validation:
# Number of data points: 3034
# Hits @10: 0.0006591957811470006
# Hits @3: 0.0
# Hits @1: 0.0
# Mean rank: 18574.32762030323
# Mean reciprocal rank: 0.0002636311252365252
# Iteration:3
# Training Time:25.678311347961426
# Loss:0.0023847087578270846
# Validation:
# Number of data points: 3034
# requests_with_retry encountered retryable exception: ('Connection aborted.', TimeoutError(10060, 'Une tentative de connexion a échoué car le parti connecté n’a pas répondu convenablement au-delà d’une certaine durée ou une connexion établie a échoué car l’hôte de connexion n’a pas répondu', None, 10060, None)). args: ('https://api.wandb.ai/files/rkbrary/ift6760-exp/3r3qvu8b/file_stream',), kwargs: {'json': {'files': {'output.log': {'offset': 38, 'content': ['2020-04-14T14:55:42.947147 Training Time:26.20589518547058\n', '2020-04-14T14:55:42.948145 Loss:0.00584277920293766\n', '2020-04-14T14:55:43.225842 Validation:\n', '2020-04-14T14:55:43.434324 Number of data points: 3034\n', '2020-04-14T14:55:51.018521 Hits @10: 0.0006591957811470006\n', '2020-04-14T14:55:51.019534 Hits @3: 0.0\n', '2020-04-14T14:55:51.020517 Hits @1: 0.0\n', '2020-04-14T14:55:51.022479 Mean rank: 18574.32762030323\n', '2020-04-14T14:55:51.023477 Mean reciprocal rank: 0.0002636311252365252\n']}}}}
# requests_with_retry encountered retryable exception: ('Connection aborted.', TimeoutError(10060, 'Une tentative de connexion a échoué car le parti connecté n’a pas répondu convenablement au-delà d’une certaine durée ou une connexion établie a échoué car l’hôte de connexion n’a pas répondu', None, 10060, None)). args: ('https://api.wandb.ai/files/rkbrary/ift6760-exp/1cglmw90/file_stream',), kwargs: {'json': {'files': {'output.log': {'offset': 38, 'content': ['2020-04-14T14:55:42.947147 Training Time:26.20589518547058\n', '2020-04-14T14:55:42.948145 Loss:0.00584277920293766\n', '2020-04-14T14:55:43.225842 Validation:\n', '2020-04-14T14:55:43.434324 Number of data points: 3034\n', '2020-04-14T14:55:51.018521 Hits @10: 0.0006591957811470006\n', '2020-04-14T14:55:51.019534 Hits @3: 0.0\n', '2020-04-14T14:55:51.020517 Hits @1: 0.0\n', '2020-04-14T14:55:51.022479 Mean rank: 18574.32762030323\n', '2020-04-14T14:55:51.023477 Mean reciprocal rank: 0.0002636311252365252\n']}}}}
# requests_with_retry encountered retryable exception: ('Connection aborted.', TimeoutError(10060, 'Une tentative de connexion a échoué car le parti connecté n’a pas répondu convenablement au-delà d’une certaine durée ou une connexion établie a échoué car l’hôte de connexion n’a pas répondu', None, 10060, None)). args: ('https://api.wandb.ai/files/rkbrary/ift6760-exp/3r3qvu8b/file_stream',), kwargs: {'json': {'files': {'output.log': {'offset': 41, 'content': ['2020-04-14T14:55:43.434324 Number of data points: 3034\n', '2020-04-14T14:55:51.018521 Hits @10: 0.0006591957811470006\n', '2020-04-14T14:55:51.019534 Hits @3: 0.0\n', '2020-04-14T14:55:51.020517 Hits @1: 0.0\n', '2020-04-14T14:55:51.022479 Mean rank: 18574.32762030323\n', '2020-04-14T14:55:51.023477 Mean reciprocal rank: 0.0002636311252365252\n']}, 'wandb-history.jsonl': {'offset': 2, 'content': ['{"Hits @10": 0.0006591957811470006, "Hits @3": 0.0, "Hits @1": 0.0, "MRR": 0.0002636311252365252, "_runtime": 80.49591755867004, "_timestamp": 1586876151.0075219, "_step": 1}\n', '{"Hits @10": 0.0006591957811470006, "Hits @3": 0.0, "Hits @1": 0.0, "MRR": 0.0002636311252365252, "_runtime": 80.49591755867004, "_timestamp": 1586876151.0075219, "_step": 1}\n']}, 'wandb-summary.json': {'offset': 0, 'content': ['{"graph_0": {"_type": "graph-file", "path": "media/graph/graph_0_summary_0f1cee1b.graph.json", "sha256": "0f1cee1bf82c3cd82065ad085700d549bd111c3b74c20f8491dd15e3af44a860", "size": 1540}, "Hits @1": 0.0, "MRR": 0.0002636311252365252, "Hits @10": 0.0006591957811470006, "_timestamp": 1586876151.0075219, "Hits @3": 0.0, "_step": 1, "_runtime": 80.49591755867004}\n']}}}}
# Hits @10: 0.0003295978905735003
# Hits @3: 0.0
# Hits @1: 0.0
# Mean rank: 17922.826631509557
# Mean reciprocal rank: 0.00024533146014202154
# Iteration:4
# Training Time:25.58119225502014
# Loss:0.0014926745782566952
# Validation:
# Number of data points: 3034
# Hits @10: 0.0003295978905735003
# Hits @3: 0.0
# Hits @1: 0.0
# Mean rank: 17421.254779169412
# Mean reciprocal rank: 0.000265843048221468
# Iteration:5
# Training Time:25.12878179550171
# Loss:0.0011350392600075459
# Validation:
# Number of data points: 3034
# Hits @10: 0.0003295978905735003
# Hits @3: 0.0
# Hits @1: 0.0
# Mean rank: 16965.525708635465
# Mean reciprocal rank: 0.0003338106298447524
# Iteration:6
# Training Time:24.561511278152466
# Loss:0.0009576130702658753
# Validation:
# Number of data points: 3034
# Hits @10: 0.0
# Hits @3: 0.0
# Hits @1: 0.0
# Mean rank: 16520.66545814107
# Mean reciprocal rank: 0.0004988693563917559
# Iteration:7
# Training Time:25.340900421142578
# Loss:0.0008544254018334856
# Validation:
# Number of data points: 3034
# Hits @10: 0.000988793671720501
# Hits @3: 0.0003295978905735003
# Hits @1: 0.0003295978905735003
# Mean rank: 16164.882663150956
# Mean reciprocal rank: 0.0011710092606027473
# Iteration:8
# Training Time:23.90656352043152
# Loss:0.0007901828549146442
# Validation:
# Number of data points: 3034
# Hits @10: 0.0016479894528675016
# Hits @3: 0.0006591957811470006
# Hits @1: 0.0
# Mean rank: 15848.294990112063
# Mean reciprocal rank: 0.0015925101649338104
# Iteration:9
# Training Time:23.495696783065796
# Loss:0.0007448957065566325
# Validation:
# Number of data points: 3034
# Hits @10: 0.00988793671720501
# Hits @3: 0.0042847725774555045
# Hits @1: 0.002966381015161503
# Mean rank: 15562.232366512855
# Mean reciprocal rank: 0.0056953020305256395
# Iteration:10
# Training Time:23.89794945716858
# Loss:0.0007109394449491422
# Validation:
# Number of data points: 3034
# Hits @10: 0.023731048121292023
# Hits @3: 0.01120632827949901
# Hits @1: 0.004943968358602505
# Mean rank: 15359.723796967699
# Mean reciprocal rank: 0.011144828767901916
# Iteration:11
# Training Time:24.087625741958618
# Loss:0.0006841705398778366
# Validation:
# Number of data points: 3034
# Hits @10: 0.027356624917600526
# Hits @3: 0.013183915622940013
# Hits @1: 0.005603164139749505
# Mean rank: 15152.056690837178
# Mean reciprocal rank: 0.013034335138693379
# Iteration:12
# Training Time:23.708696365356445
# Loss:0.0006603537370044161
# Validation:
# Number of data points: 3034
# Hits @10: 0.02933421226104153
# Hits @3: 0.015491100856954515
# Hits @1: 0.0065919578114700065
# Mean rank: 14959.348055372446
# Mean reciprocal rank: 0.01480465547594714
# Iteration:13
# Training Time:25.73715043067932
# Loss:0.0006383392372837579
# Validation:
# Number of data points: 3034
# Hits @10: 0.034278180619644036
# Hits @3: 0.016150296638101518
# Hits @1: 0.008569545154911009
# Mean rank: 14846.352010547133
# Mean reciprocal rank: 0.01662911446564755
# Iteration:14
# Training Time:24.785059690475464
# Loss:0.0006201379056888777
# Validation:
# Number of data points: 3034
# Hits @10: 0.03361898483849703
# Hits @3: 0.015491100856954515
# Hits @1: 0.008899143045484509
# Mean rank: 14691.439683586024
# Mean reciprocal rank: 0.01661685266526068
# Iteration:15
# Training Time:24.36568021774292
# Loss:0.0006009471419096832
# Validation:
# Number of data points: 3034
# Hits @10: 0.036585365853658534
# Hits @3: 0.017139090309822018
# Hits @1: 0.00988793671720501
# Mean rank: 14621.849044166118
# Mean reciprocal rank: 0.018614600882691585
# Iteration:16
# Training Time:25.078587532043457
# Loss:0.0005854862314176706
# Validation:
# Number of data points: 3034
# Hits @10: 0.03823335530652604
# Hits @3: 0.01812788398154252
# Hits @1: 0.01054713249835201
# Mean rank: 14601.94858272907
# Mean reciprocal rank: 0.019383939328965785
# Iteration:17
# Training Time:25.861820459365845
# Loss:0.0005694956115355164
# Validation:
# Number of data points: 3034
# Hits @10: 0.04119973632168754
# Hits @3: 0.02241265655899802
# Hits @1: 0.010876730388925511
# Mean rank: 14640.050428477258
# Mean reciprocal rank: 0.02106568262107229
# Iteration:18
# Training Time:26.301894664764404
# Loss:0.0005534628237282831
# Validation:
# Number of data points: 3034
# Hits @10: 0.04284772577455504
# Hits @3: 0.022083058668424523
# Hits @1: 0.00988793671720501
# Mean rank: 14746.238958470665
# Mean reciprocal rank: 0.020748025898604937
# Iteration:19
# Training Time:25.826929807662964
# Loss:0.0005401411487288039
# Validation:
# Number of data points: 3034
# Hits @10: 0.04383651944627554
# Hits @3: 0.026038233355306525
# Hits @1: 0.014172709294660513
# Mean rank: 14833.834871456822
# Mean reciprocal rank: 0.02461558846607097
# Iteration:20
# Training Time:26.043213605880737
# Loss:0.000531722881673822
# Validation:
# Number of data points: 3034
# Hits @10: 0.04812129202373105
# Hits @3: 0.023731048121292023
# Hits @1: 0.013843111404087014
# Mean rank: 14954.3740936058
# Mean reciprocal rank: 0.024670063765482822
# Iteration:21
# Training Time:25.72826886177063
# Loss:0.0005202300827720688
# Validation:
# Number of data points: 3034
# Hits @10: 0.04680290046143705
# Hits @3: 0.026367831245880026
# Hits @1: 0.016809492419248517
# Mean rank: 15094.153922214899
# Mean reciprocal rank: 0.026740596526515756
# Iteration:22
# Training Time:25.102948904037476
# Loss:0.0005076538685309163
# Validation:
# Number of data points: 3034
# Hits @10: 0.05009887936717205
# Hits @3: 0.026367831245880026
# Hits @1: 0.016479894528675015
# Mean rank: 15090.768951878708
# Mean reciprocal rank: 0.026938962183789335
# Iteration:23
# Training Time:26.167467832565308
# Loss:0.0004971268296595925
# Validation:
# Number of data points: 3034
# Hits @10: 0.04482531311799604
# Hits @3: 0.028345418589321027
# Hits @1: 0.015820698747528016
# Mean rank: 15281.186552406065
# Mean reciprocal rank: 0.026757251755687494
# Iteration:24
# Training Time:25.433964252471924
# Loss:0.0004875613948736917
# Validation:
# Number of data points: 3034
# Hits @10: 0.05207646671061305
# Hits @3: 0.02900461437046803
# Hits @1: 0.016150296638101518
# Mean rank: 15527.4825313118
# Mean reciprocal rank: 0.027628160229656848
# Iteration:25
# Training Time:25.159715175628662
# Loss:0.000476852692270153
# Validation:
# Number of data points: 3034
# Hits @10: 0.05372445616348055
# Hits @3: 0.027686222808174028
# Hits @1: 0.01812788398154252
# Mean rank: 15561.239947264337
# Mean reciprocal rank: 0.028576930104611407
# Iteration:26
# Training Time:25.54426074028015
# Loss:0.00046851901193214974
# Validation:
# Number of data points: 3034
# Hits @10: 0.05702043506921556
# Hits @3: 0.03361898483849703
# Hits @1: 0.02043506921555702
# Mean rank: 15666.754449571523
# Mean reciprocal rank: 0.031764217356269615
# Iteration:27
# Training Time:25.118329524993896
# Loss:0.0004599005922602988
# Validation:
# Number of data points: 3034
# Hits @10: 0.05471324983520105
# Hits @3: 0.032300593276203035
# Hits @1: 0.01911667765326302
# Mean rank: 15730.698088332234
# Mean reciprocal rank: 0.030899314699046693
# Iteration:28
# Training Time:26.124709844589233
# Loss:0.0004529743579144157
# Validation:
# Number of data points: 3034
# Hits @10: 0.05669083717864205
# Hits @3: 0.03724456163480554
# Hits @1: 0.026038233355306525
# Mean rank: 15839.94792353329
# Mean reciprocal rank: 0.03612877140540597
# Iteration:29
# Training Time:26.210859060287476
# Loss:0.0004473290265157399
# Validation:
# Number of data points: 3034
# Hits @10: 0.05273566249176005
# Hits @3: 0.036585365853658534
# Hits @1: 0.021753460777851022
# Mean rank: 16070.038562953197
# Mean reciprocal rank: 0.03345520025566704
# Iteration:30
# Training Time:26.180105924606323
# Loss:0.00044343226710596767
# Validation:
# Number of data points: 3034
# Hits @10: 0.05504284772577456
# Hits @3: 0.037574159525379035
# Hits @1: 0.023071852340145024
# Mean rank: 16312.58569545155
# Mean reciprocal rank: 0.034732211683967874
# Iteration:31
# Training Time:25.782613515853882
# Loss:0.0004333747866478237
# Validation:
# Number of data points: 3034
# Hits @10: 0.058338826631509556
# Hits @3: 0.03955174686882004
# Hits @1: 0.024060646011865524
# Mean rank: 16184.021753460778
# Mean reciprocal rank: 0.03622560665642618
# Iteration:32
# Training Time:25.42476201057434
# Loss:0.00042744279522645537
# Validation:
# Number of data points: 3034
# Hits @10: 0.057350032959789056
# Hits @3: 0.04054054054054054
# Hits @1: 0.026697429136453527
# Mean rank: 16497.192814765986
# Mean reciprocal rank: 0.037955667448847874
# Iteration:33
# Training Time:25.654162168502808
# Loss:0.0004240218066269348
# Validation:
# Number of data points: 3034
# Hits @10: 0.061305207646671064
# Hits @3: 0.043177323665128546
# Hits @1: 0.02801582069874753
# Mean rank: 16480.90639419908
# Mean reciprocal rank: 0.039665864811974774
# Iteration:34
# Training Time:25.876776695251465
# Loss:0.0004184479389051107
# Validation:
# Number of data points: 3034
# Hits @10: 0.05800922874093606
# Hits @3: 0.04482531311799604
# Hits @1: 0.02900461437046803
# Mean rank: 16561.624588002636
# Mean reciprocal rank: 0.040253327091678295
# Iteration:35
# Training Time:26.081243753433228
# Loss:0.0004133694492031256
# Validation:
# Number of data points: 3034
# Hits @10: 0.06394199077125906
# Hits @3: 0.045484508899143045
# Hits @1: 0.03098220171390903
# Mean rank: 16601.450560316414
# Mean reciprocal rank: 0.042527709695278165
# Iteration:36
# Training Time:26.258759260177612
# Loss:0.0004067621767704546
# Validation:
# Number of data points: 3034
# Hits @10: 0.06690837178642056
# Hits @3: 0.04713249835201055
# Hits @1: 0.032300593276203035
# Mean rank: 16777.34574818721
# Mean reciprocal rank: 0.04401423132724808
# Iteration:37
# Training Time:26.181034088134766
# Loss:0.0004023239806025538
# Validation:
# Number of data points: 3034
# Hits @10: 0.07251153592617007
# Hits @3: 0.04976928147659855
# Hits @1: 0.03361898483849703
# Mean rank: 16884.473302570863
# Mean reciprocal rank: 0.04595915687749435
# Iteration:38
# Training Time:25.38420271873474
# Loss:0.0003984396878800447
# Validation:
# Number of data points: 3034
# Hits @10: 0.07350032959789057
# Hits @3: 0.05075807514831905
# Hits @1: 0.034607778510217534
# Mean rank: 16925.829268292684
# Mean reciprocal rank: 0.047518798678185564
# Iteration:39
# Training Time:25.252204656600952
# Loss:0.00039464342957165773
# Validation:
# Number of data points: 3034
# Hits @10: 0.07284113381674358
# Hits @3: 0.05207646671061305
# Hits @1: 0.038562953197099535
# Mean rank: 16911.944297956492
# Mean reciprocal rank: 0.050145464498130045
# Iteration:40
# Training Time:25.44092321395874
# Loss:0.00039092046643187566
# Validation:
# Number of data points: 3034
# Hits @10: 0.07547791694133157
# Hits @3: 0.05570204350692155
# Hits @1: 0.03724456163480554
# Mean rank: 17088.463085036256
# Mean reciprocal rank: 0.05079580630464952
# Iteration:41
# Training Time:25.322258472442627
# Loss:0.000386829833454177
# Validation:
# Number of data points: 3034
# Hits @10: 0.07448912326961107
# Hits @3: 0.05767963085036256
# Hits @1: 0.04152933421226104
# Mean rank: 17330.021753460776
# Mean reciprocal rank: 0.053599807803897746
# Iteration:42
# Training Time:25.686089992523193
# Loss:0.0003843541274299766
# Validation:
# Number of data points: 3034
# Hits @10: 0.07481872116018458
# Hits @3: 0.057350032959789056
# Hits @1: 0.04152933421226104
# Mean rank: 17090.4581410679
# Mean reciprocal rank: 0.053694316600814654
# Iteration:43
# Training Time:26.3889319896698
# Loss:0.0003880833503527855
# Validation:
# Number of data points: 3034
# Hits @10: 0.07778510217534608
# Hits @3: 0.056361239288068556
# Hits @1: 0.04087013843111404
# Mean rank: 17342.596242584048
# Mean reciprocal rank: 0.05298413481962524
# Iteration:44
# Training Time:26.015264987945557
# Loss:0.00038415196115597035
# Validation:
# Number of data points: 3034
# Hits @10: 0.07778510217534608
# Hits @3: 0.06163480553724456
# Hits @1: 0.044166117336849046
# Mean rank: 17465.039551746868
# Mean reciprocal rank: 0.05641972770963164
# Iteration:45
# Training Time:24.39681339263916
# Loss:0.0003786490759549951
# Validation:
# Number of data points: 3034
# Hits @10: 0.08503625576796309
# Hits @3: 0.06262359920896507
# Hits @1: 0.04779169413315755
# Mean rank: 17291.950889914304
# Mean reciprocal rank: 0.06053815525317427
# Iteration:46
# Training Time:25.160171508789062
# Loss:0.0003750378716061495
# Validation:
# Number of data points: 3034
# Hits @10: 0.08338826631509558
# Hits @3: 0.06789716545814106
# Hits @1: 0.04976928147659855
# Mean rank: 17540.543836519446
# Mean reciprocal rank: 0.062124534423963186
# Iteration:47
# Training Time:25.350189685821533
# Loss:0.00037251051915416
# Validation:
# Number of data points: 3034
# Hits @10: 0.08899143045484509
# Hits @3: 0.06921555702043507
# Hits @1: 0.052406064601186554
# Mean rank: 17543.33882663151
# Mean reciprocal rank: 0.06528199686562662
# Iteration:48
# Training Time:24.6510591506958
# Loss:0.0003700253147054726
# Validation:
# Number of data points: 3034
# Hits @10: 0.0903098220171391
# Hits @3: 0.07152274225444957
# Hits @1: 0.055372445616348055
# Mean rank: 17531.40804218853
# Mean reciprocal rank: 0.06777018041233943
# Iteration:49
# Training Time:24.16067147254944
# Loss:0.00036868207200928786
# Validation:
# Number of data points: 3034
# Hits @10: 0.0926170072511536
# Hits @3: 0.07218193803559657
# Hits @1: 0.05603164139749506
# Mean rank: 17412.123928806857
# Mean reciprocal rank: 0.06869720706142682
# Iteration:50
# Training Time:24.918072938919067
# Loss:0.0003672656122739361
# Validation:
# Number of data points: 3034
# Hits @10: 0.09294660514172709
# Hits @3: 0.07284113381674358
# Hits @1: 0.05800922874093606
# Mean rank: 17500.26994067238
# Mean reciprocal rank: 0.06988011249105522
# Iteration:51
# Training Time:24.11025834083557
# Loss:0.0003659240985092458
# Validation:
# Number of data points: 3034
# Hits @10: 0.09162821357943308
# Hits @3: 0.07646671061305207
# Hits @1: 0.05932762030323006
# Mean rank: 17432.25939353988
# Mean reciprocal rank: 0.07203323064750233
# Iteration:52
# Training Time:24.631285429000854
# Loss:0.00036435274187554144
# Validation:
# Number of data points: 3034
# Hits @10: 0.0975609756097561
# Hits @3: 0.07976268951878708
# Hits @1: 0.06031641397495056
# Mean rank: 17619.932762030323
# Mean reciprocal rank: 0.0739636816308157
# Iteration:53
# Training Time:24.571513891220093
# Loss:0.0003626357066333556
# Validation:
# Number of data points: 3034
# Hits @10: 0.0992089650626236
# Hits @3: 0.07547791694133157
# Hits @1: 0.05932762030323006
# Mean rank: 17529.914304548452
# Mean reciprocal rank: 0.07236472118159351
# Iteration:54
# Training Time:24.1506769657135
# Loss:0.0003615841762208655
# Validation:
# Number of data points: 3034
# Hits @10: 0.1021753460777851
# Hits @3: 0.08239947264337508
# Hits @1: 0.06427158866183257
# Mean rank: 17696.29927488464
# Mean reciprocal rank: 0.07759630181318566
# Iteration:55
# Training Time:25.20727849006653
# Loss:0.0003620129759902213
# Validation:
# Number of data points: 3034
# Hits @10: 0.10184574818721161
# Hits @3: 0.08075148319050758
# Hits @1: 0.06262359920896507
# Mean rank: 17811.848714568227
# Mean reciprocal rank: 0.07606106064778279
# Iteration:56
# Training Time:25.23478627204895
# Loss:0.0003619909105317431
# Validation:
# Number of data points: 3034
# Hits @10: 0.0992089650626236
# Hits @3: 0.08239947264337508
# Hits @1: 0.06196440342781806
# Mean rank: 17656.714897824655
# Mean reciprocal rank: 0.07595162849527845
# Iteration:57
# Training Time:24.683257579803467
# Loss:0.0003603437945777944
# Validation:
# Number of data points: 3034
# Hits @10: 0.1011865524060646
# Hits @3: 0.08404746209624259
# Hits @1: 0.06558998022412657
# Mean rank: 17687.973632168752
# Mean reciprocal rank: 0.0786552154120161
# Iteration:58
# Training Time:25.52474045753479
# Loss:0.0003596782964706736
# Validation:
# Number of data points: 3034
# Hits @10: 0.1044825313117996
# Hits @3: 0.08305866842452209
# Hits @1: 0.06361239288068557
# Mean rank: 17689.865194462756
# Mean reciprocal rank: 0.07765069905128953
# Iteration:59
# Training Time:25.03228187561035
# Loss:0.00035856059567123967
# Validation:
# Number of data points: 3034
# Hits @10: 0.10184574818721161
# Hits @3: 0.08437705998681608
# Hits @1: 0.06493078444297956
# Mean rank: 17687.44825313118
# Mean reciprocal rank: 0.07855701443450329
# Iteration:60
# Training Time:24.887818813323975
# Loss:0.00035739959042165167
# Validation:
# Number of data points: 3034
# Hits @10: 0.1025049439683586
# Hits @3: 0.08404746209624259
# Hits @1: 0.06690837178642056
# Mean rank: 17655.285102175345
# Mean reciprocal rank: 0.07982580870436641
# Iteration:61
# Training Time:24.8568377494812
# Loss:0.0003573897477521391
# Validation:
# Number of data points: 3034
# Hits @10: 0.1054713249835201
# Hits @3: 0.08866183256427158
# Hits @1: 0.06888595912986156
# Mean rank: 17630.28279499011
# Mean reciprocal rank: 0.08282675871393226
# Iteration:62
# Training Time:25.561618328094482
# Loss:0.00037074303115114675
# Validation:
# Number of data points: 3034
# Hits @10: 0.10283454185893211
# Hits @3: 0.08602504943968359
# Hits @1: 0.06756756756756757
# Mean rank: 17749.331905075807
# Mean reciprocal rank: 0.08038293183124558
# Iteration:63
# Training Time:26.056173086166382
# Loss:0.0003638309258541328
# Validation:
# Number of data points: 3034
# Hits @10: 0.10382333553065261
# Hits @3: 0.08569545154911008
# Hits @1: 0.06624917600527357
# Mean rank: 17713.79235332894
# Mean reciprocal rank: 0.07981838309977048
# Iteration:64
# Training Time:26.06836771965027
# Loss:0.0003584753866241851
# Validation:
# Number of data points: 3034
# Hits @10: 0.1084377059986816
# Hits @3: 0.08734344100197759
# Hits @1: 0.06558998022412657
# Mean rank: 17576.137112722477
# Mean reciprocal rank: 0.08138574935544149
# Iteration:65
# Training Time:25.90617871284485
# Loss:0.00035638353536495755
# Validation:
# Number of data points: 3034
# Hits @10: 0.11008569545154911
# Hits @3: 0.0893210283454186
# Hits @1: 0.06723796967699407
# Mean rank: 17500.911667765326
# Mean reciprocal rank: 0.08264554610094829
# Iteration:66
# Training Time:25.838881015777588
# Loss:0.0003553723998394021
# Validation:
# Number of data points: 3034
# Hits @10: 0.11008569545154911
# Hits @3: 0.09096901779828609
# Hits @1: 0.06855636123928807
# Mean rank: 17624.62096242584
# Mean reciprocal rank: 0.08373080897289581
# Iteration:67
# Training Time:25.856723070144653
# Loss:0.0003545747470589433
# Validation:
# Number of data points: 3034
# Hits @10: 0.11074489123269611
# Hits @3: 0.0903098220171391
# Hits @1: 0.06954515491100857
# Mean rank: 17474.04054054054
# Mean reciprocal rank: 0.0840843831309666
# Iteration:68
# Training Time:25.800376176834106
# Loss:0.0003543098429283521
# Validation:
# Number of data points: 3034
# Hits @10: 0.1114040870138431
# Hits @3: 0.0926170072511536
# Hits @1: 0.07152274225444957
# Mean rank: 17739.75939353988
# Mean reciprocal rank: 0.08574546051306285
# Iteration:69
# Training Time:24.638728618621826
# Loss:0.00035364444033098475
# Validation:
# Number of data points: 3034
# Hits @10: 0.11437046802900462
# Hits @3: 0.09393539881344759
# Hits @1: 0.06921555702043507
# Mean rank: 17461.784772577455
# Mean reciprocal rank: 0.08524979312484998
# Iteration:70
# Training Time:26.199246168136597
# Loss:0.00035292338866832284
# Validation:
# Number of data points: 3034
# Hits @10: 0.11206328279499012
# Hits @3: 0.09492419248516809
# Hits @1: 0.07086354647330258
# Mean rank: 17604.65524060646
# Mean reciprocal rank: 0.08699086736213464
# Iteration:71
# Training Time:26.25858211517334
# Loss:0.0003522301546107768
# Validation:
# Number of data points: 3034
# Hits @10: 0.11107448912326962
# Hits @3: 0.0936058009228741
# Hits @1: 0.07317073170731707
# Mean rank: 17576.455174686882
# Mean reciprocal rank: 0.08716314812403714
# Iteration:72
# Training Time:25.437355756759644
# Loss:0.00035183275213570035
# Validation:
# Number of data points: 3034
# Hits @10: 0.11371127224785761
# Hits @3: 0.09195781147000659
# Hits @1: 0.06987475280158208
# Mean rank: 17592.056031641398
# Mean reciprocal rank: 0.08505350072378474
# Iteration:73
# Training Time:26.13832664489746
# Loss:0.00035175816623271035
# Validation:
# Number of data points: 3034
# Hits @10: 0.11371127224785761
# Hits @3: 0.0926170072511536
# Hits @1: 0.07448912326961107
# Mean rank: 17517.829268292684
# Mean reciprocal rank: 0.08841562730799352
# Iteration:74
# Training Time:26.2408447265625
# Loss:0.0003513661678880453
# Validation:
# Number of data points: 3034
# Hits @10: 0.11535926170072512
# Hits @3: 0.0926170072511536
# Hits @1: 0.07185234014502308
# Mean rank: 17483.112392880685
# Mean reciprocal rank: 0.0867579959180809
# Iteration:75
# Training Time:25.979464054107666
# Loss:0.00035099516545658484
# Validation:
# Number of data points: 3034
# Hits @10: 0.11865524060646011
# Hits @3: 0.0942649967040211
# Hits @1: 0.07382992748846408
# Mean rank: 17441.775214238627
# Mean reciprocal rank: 0.0894483451831663
# Iteration:76
# Training Time:25.93844437599182
# Loss:0.0003501434284131187
# Validation:
# Number of data points: 3034
# Hits @10: 0.11535926170072512
# Hits @3: 0.0926170072511536
# Hits @1: 0.07481872116018458
# Mean rank: 17529.134475939354
# Mean reciprocal rank: 0.08892592337122261
# Iteration:77
# Training Time:26.126229524612427
# Loss:0.0003494932363793569
# Validation:
# Number of data points: 3034
# Hits @10: 0.11568885959129861
# Hits @3: 0.0952537903757416
# Hits @1: 0.07382992748846408
# Mean rank: 17541.81608437706
# Mean reciprocal rank: 0.08903625866635245
# Iteration:78
# Training Time:26.08522081375122
# Loss:0.00034905658365870024
# Validation:
# Number of data points: 3034
# Hits @10: 0.11470006591957811
# Hits @3: 0.0955833882663151
# Hits @1: 0.07284113381674358
# Mean rank: 17615.744232036915
# Mean reciprocal rank: 0.08831959176429563
# Iteration:79
# Training Time:25.93845224380493
# Loss:0.00034892663981070295
# Validation:
# Number of data points: 3034
# Hits @10: 0.11107448912326962
# Hits @3: 0.0962425840474621
# Hits @1: 0.07547791694133157
# Mean rank: 17643.34508899143
# Mean reciprocal rank: 0.08970414326297448
# Iteration:80
# Training Time:23.663368701934814
# Loss:0.000349420419497363
# Validation:
# Number of data points: 3034
# Hits @10: 0.11437046802900462
# Hits @3: 0.09887936717205009
# Hits @1: 0.07580751483190508
# Mean rank: 17604.06888595913
# Mean reciprocal rank: 0.09032540492506706
# Iteration:81
# Training Time:17.28077220916748
# Loss:0.00035025885363083176
# Validation:
# Number of data points: 3034
# Hits @10: 0.11568885959129861
# Hits @3: 0.09789057350032959
# Hits @1: 0.07580751483190508
# Mean rank: 17747.36058009229
# Mean reciprocal rank: 0.09044621206259737
# Iteration:82
# Training Time:17.426396369934082
# Loss:0.00034943674813995375
# Validation:
# Number of data points: 3034
# Hits @10: 0.11733684904416612
# Hits @3: 0.0972313777191826
# Hits @1: 0.07382992748846408
# Mean rank: 17634.37837837838
# Mean reciprocal rank: 0.09008920666894997
# Iteration:83
# Training Time:17.416411876678467
# Loss:0.000348514814379061
# Validation:
# Number of data points: 3034
# Hits @10: 0.11535926170072512
# Hits @3: 0.09591298615688859
# Hits @1: 0.07481872116018458
# Mean rank: 17603.61008569545
# Mean reciprocal rank: 0.08959395116149241
# Iteration:84
# Training Time:17.494202613830566
# Loss:0.00034806579326830385
# Validation:
# Number of data points: 3034
# Hits @10: 0.11601845748187212
# Hits @3: 0.09789057350032959
# Hits @1: 0.07613711272247857
# Mean rank: 17657.646011865523
# Mean reciprocal rank: 0.09118223515760393
# Iteration:85
# Training Time:17.873188018798828
# Loss:0.00034779000610873944
# Validation:
# Number of data points: 3034
# Hits @10: 0.11437046802900462
# Hits @3: 0.0992089650626236
# Hits @1: 0.07745550428477257
# Mean rank: 17464.359591298617
# Mean reciprocal rank: 0.09196436485377817
# Iteration:86
# Training Time:17.986903190612793
# Loss:0.00034814465431903135
# Validation:
# Number of data points: 3034
# Hits @10: 0.11502966381015162
# Hits @3: 0.09789057350032959
# Hits @1: 0.07679630850362558
# Mean rank: 17786.330257086356
# Mean reciprocal rank: 0.09130846480349072
# Iteration:87
# Training Time:18.041740655899048
# Loss:0.0003483177685755974
# Validation:
# Number of data points: 3034
# Hits @10: 0.11865524060646011
# Hits @3: 0.0985497692814766
# Hits @1: 0.07514831905075807
# Mean rank: 17636.538233355306
# Mean reciprocal rank: 0.09087280039031251
# Iteration:88
# Training Time:18.12052822113037
# Loss:0.0003479000366240425
# Validation:
# Number of data points: 3034
# Hits @10: 0.11634805537244562
# Hits @3: 0.09789057350032959
# Hits @1: 0.07679630850362558
# Mean rank: 17626.122610415292
# Mean reciprocal rank: 0.0910639889983097
# Iteration:89
# Training Time:18.0327627658844
# Loss:0.00034882864762346823
# Validation:
# Number of data points: 3034
# Hits @10: 0.11799604482531312
# Hits @3: 0.09690177982860909
# Hits @1: 0.07547791694133157
# Mean rank: 17760.16117336849
# Mean reciprocal rank: 0.09102016114511323
# Iteration:90
# Training Time:17.94197130203247
# Loss:0.00034732311983710863
# Validation:
# Number of data points: 3034
# Hits @10: 0.11634805537244562
# Hits @3: 0.0998681608437706
# Hits @1: 0.07976268951878708
# Mean rank: 17694.64403427818
# Mean reciprocal rank: 0.09355240276591954
# Iteration:91
# Training Time:17.939016103744507
# Loss:0.0003464784633046882
# Validation:
# Number of data points: 3034
# Hits @10: 0.11700725115359262
# Hits @3: 0.0992089650626236
# Hits @1: 0.08009228740936059
# Mean rank: 17604.358272907055
# Mean reciprocal rank: 0.0939112471021894
# Iteration:92
# Training Time:17.96693754196167
# Loss:0.00034616658714940957
# Validation:
# Number of data points: 3034
# Hits @10: 0.11799604482531312
# Hits @3: 0.0985497692814766
# Hits @1: 0.07910349373764008
# Mean rank: 17552.28246539222
# Mean reciprocal rank: 0.09352015668179055
# Iteration:93
# Training Time:17.478246450424194
# Loss:0.0003467554561826597
# Validation:
# Number of data points: 3034
# Hits @10: 0.11437046802900462
# Hits @3: 0.1008569545154911
# Hits @1: 0.08075148319050758
# Mean rank: 17807.825972313778
# Mean reciprocal rank: 0.09428776369139491
# Iteration:94
# Training Time:17.86421775817871
# Loss:0.0003487246154486136
# Validation:
# Number of data points: 3034
# Hits @10: 0.11766644693473961
# Hits @3: 0.09887936717205009
# Hits @1: 0.07877389584706658
# Mean rank: 17792.181608437706
# Mean reciprocal rank: 0.09308958139897783
# Iteration:95
# Training Time:17.880171060562134
# Loss:0.00034806878538802267
# Validation:
# Number of data points: 3034
# Hits @10: 0.11700725115359262
# Hits @3: 0.1015161502966381
# Hits @1: 0.08042188529993408
# Mean rank: 17696.44264996704
# Mean reciprocal rank: 0.09450226758271087
# Iteration:96
# Training Time:17.745530605316162
# Loss:0.00034597880915332007
# Validation:
# Number of data points: 3034
# Hits @10: 0.11865524060646011
# Hits @3: 0.10184574818721161
# Hits @1: 0.07943309162821358
# Mean rank: 17582.74620962426
# Mean reciprocal rank: 0.09440699553161791
# Iteration:97
# Training Time:17.98688530921936
# Loss:0.0003465809458440406
# Validation:
# Number of data points: 3034
# Hits @10: 0.11997363216875412
# Hits @3: 0.1008569545154911
# Hits @1: 0.08075148319050758
# Mean rank: 17615.438694792352
# Mean reciprocal rank: 0.09488541514456539
# Iteration:98
# Training Time:18.271124839782715
# Loss:0.0003466029453065089
# Validation:
# Number of data points: 3034
# Hits @10: 0.11865524060646011
# Hits @3: 0.1021753460777851
# Hits @1: 0.08075148319050758
# Mean rank: 17694.432762030323
# Mean reciprocal rank: 0.09517509046330438
# Iteration:99
# Training Time:18.045727729797363
# Loss:0.00034628337704983186
# Validation:
# Number of data points: 3034
# Hits @10: 0.11634805537244562
# Hits @3: 0.1001977587343441
# Hits @1: 0.08009228740936059
# Mean rank: 17713.20105471325
# Mean reciprocal rank: 0.09430243330906145
# Iteration:100
# Training Time:17.561021089553833
# Loss:0.00034524997668406387
# Validation:
# Number of data points: 3034
# Hits @10: 0.12030323005932762
# Hits @3: 0.1025049439683586
# Hits @1: 0.08108108108108109
# Mean rank: 17613.86189848385
# Mean reciprocal rank: 0.09591697006608171
# Test:
# Number of data points: 3134
# Hits @10: 0.14326738991703894
# Hits @3: 0.11933631142310147
# Hits @1: 0.09668155711550734
# Mean rank: 18016.168474792597
# Mean reciprocal rank: 0.11223206538299957
# Testing time:5.073427438735962

# %%
type(model)

# %%
args.bk

# %%
import wandb
wandb.login('1e505430989c86455d2d70e1ef990b4bc50cb69c')
from load_data import Data
import numpy as np
import torch
import time
from collections import defaultdict
from model import *
# from model_sym import *
from torch.optim.lr_scheduler import ExponentialLR
import argparse
import os

# %%
dataset = "WN18RR"
data_dir = "data/%s/" % dataset
d = Data(data_dir=data_dir, reverse=False)
kwargs = {"input_dropout": 0.2, "hidden_dropout1": 0.2,
                       "hidden_dropout2": 0.3, "bk": False}

# %%
model = TuckER(d,200,30,**kwargs)
state = wandb.restore('model_state.pth',run_path='rkbrary/ift6760-exp/1wtu4v7p') #rkbrary/ift6760-exp/1wtu4v7p
checkpoint = torch.load(state.name)
# checkpoint=torch.load('wandb/run-20200413_055149-ihc8l1ta/model_state_new.pth')
model.load_state_dict(checkpoint['model_state_dict'])

# %%
# state.name

# %%
W=experiment.model.W.data.to('cpu')
R=experiment.model.R.weight.data.to('cpu')

# %%
W_r=torch.einsum('ijk,ni->njk',W,R)
constraints=torch.tensor([0,1,-1,0,-1,-1,-1,-1,1,0,1])

# %%
for i in range(len(W_r)):
    print(torch.norm(W_r[i]+W_r[i].t()),torch.norm(W_r[i]-W_r[i].t()), constraints[i], d.relations[i])

# %%
# E=model.E.weight.data

# %%
model.cuda()
model.eval()

# %%
hits = []
ranks = []
for i in range(10):
    hits.append([])
true_rel=np.zeros(len(d.relations))
false_rel=np.zeros(len(d.relations))
entity_idxs = {d.entities[i]:i for i in range(len(d.entities))}
relation_idxs = {d.relations[i]:i for i in range(len(d.relations))}
def get_data_idxs(data):
    data_idxs = [(entity_idxs[data[i][0]], relation_idxs[data[i][1]], \
                  entity_idxs[data[i][2]]) for i in range(len(data))]
    return data_idxs

def get_er_vocab(data):
    er_vocab = defaultdict(list)
    for triple in data:
        er_vocab[(triple[0], triple[1])].append(triple[2])  # may contain multiple connections (exemple hyponym)
    return er_vocab

def get_batch(er_vocab, er_vocab_pairs, idx):
    batch = er_vocab_pairs[idx:idx+128]
    targets = np.zeros((len(batch), len(d.entities)))
    for idx, pair in enumerate(batch):
        targets[idx, er_vocab[pair]] = 1.
    targets = torch.FloatTensor(targets)
    return np.array(batch), targets

test_data_idxs = get_data_idxs(d.test_data)
er_vocab = get_er_vocab(get_data_idxs(d.data))

for i in range(0, len(test_data_idxs), 128):
    data_batch, _ = get_batch(er_vocab, test_data_idxs, i)
    e1_idx = torch.tensor(data_batch[:,0]).type(torch.LongTensor).cuda()
    r_idx = torch.tensor(data_batch[:,1]).type(torch.LongTensor).cuda()
    e2_idx = torch.tensor(data_batch[:,2])
    predictions = experiment.model.forward(e1_idx, r_idx)
    
            
    for j in range(data_batch.shape[0]):
        filt = er_vocab[(data_batch[j][0], data_batch[j][1])]
        if len(filt)>1:print(r_idx[j],len(filt))
        target_value = predictions[j,e2_idx[j]].item()
        predictions[j, filt] = 0.0
        predictions[j, e2_idx[j]] = target_value
    
    pred_idx = torch.argmax(predictions, dim=1).to('cpu')
    for i in range(len(pred_idx)):
        if (pred_idx[i]==e2_idx[i]): true_rel[r_idx[i]]+=1
        else: false_rel[r_idx[i]]+=1

    sort_values, sort_idxs = torch.sort(predictions, dim=1, descending=True)

    sort_idxs = sort_idxs.cpu().numpy()
    for j in range(data_batch.shape[0]):
        rank = np.where(sort_idxs[j]==e2_idx[j].item())[0][0]
        ranks.append(rank+1)

        for hits_level in range(10):
            if rank <= hits_level:
                hits[hits_level].append(1.0)
            else:
                hits[hits_level].append(0.0)

# %%
d.relations

# %%
np.mean(hits[0])

# %%
constraints=[0,1,-1,0,-1,-1,-1,-1,1,0,1]
d.relations
sym=[]
for i in constraints:
    if i==0: sym.append('any')
    elif i==1: sym.append('symmetric')
    else: sym.append('antisymmetric')

# %%
import pandas as pd
df=pd.DataFrame(data=[sym,true_rel,false_rel,true_rel+false_rel,true_rel/(true_rel+false_rel),false_rel/(true_rel+false_rel)],index=['Property','Pos','Neg','Total','Pos_Rate','Neg_Rate'],columns=d.relations)
df

# %%
true_rel

# %%
false_rel

# %%
false_rel+true_rel

# %%
true_rel/(true_rel+false_rel)

# %%
false_rel/(true_rel+false_rel)

# %%
sum(true_rel+false_rel)

# %%
score=[]
for e in E:
    score=torch.sigmoid(torch.einsum('j,ijk,lk->il',e,W_r,E))
    score.size()

# %%
experiment.retrain(2, 'rkbrary/ift6760-exp/ihc8l1ta', 'model_state_new.pth')

# %%
get_data_idxs(d.test_data)

# %%
experiment.get_data_idxs(d.test_data)
